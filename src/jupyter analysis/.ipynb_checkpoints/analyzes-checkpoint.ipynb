# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("../files/analyze/average_times_each_record/heapsort_7500000.csv").head(10)
dataset.rename(columns={"Average Time(ms)": "Tempo de execução"}, errors="raise")

hpPlot = dataset.plot(title='HeapSort')
hpPlot.set_xlabel("Execução")
hpPlot.set_ylabel("Tempo (ms)")
# Out:
# Text(0, 0.5, 'Tempo (ms)')
